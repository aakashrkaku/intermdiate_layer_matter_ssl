# %%
! python3 ssl_mocov2_bt.py --data-path '/gpfs/data/razavianlab/home/ark576/datasets/breast-hist/' --save-path '/gpfs/data/razavianlab/home/ark576/ssl_models_ckpt/'
# Out:
# /gpfs/home/ark576/.conda/envs/py37/lib/python3.7/site-packages/pl_bolts/utils/warnings.py:32: UserWarning: You want to use `gym` which is not installed yet, install it with `pip install gym`.
#   f' install it with `pip install {pypi_name}`.' + extra_text
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Set SLURM handle signals.
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | encoder_q | ResNet     | 23.8 M
# 1 | encoder_k | ResNet     | 23.8 M
# 2 | p1        | Projection | 8.9 M
# 3 | p2        | Projection | 9.4 M
# 4 | p3        | Projection | 10.5 M
# 5 | p4        | Projection | 12.6 M
# -----------------------------------------
# 65.2 M    Trainable params
# 23.8 M    Non-trainable params
# 89.0 M    Total params
# Epoch 0:  66%|█▎| 4504/6824 [1:08:43<35:23,  1.09it/s, loss=6.53, v_num=1.55e+7]

# %%
! python3 fine_tune_mocov2.py --ckpt-path '/gpfs/data/razavianlab/home/ark576/ssl_models_ckpt/mocov2_all_augs_breast_cancer_hist_mse_0.25-0.25-0.25-0.25/epoch=0-val_loss=7.748.ckpt' --data-path '/gpfs/data/razavianlab/home/ark576/datasets/breast-hist/' --data-size 0.01 --save-path '/gpfs/data/razavianlab/home/ark576/ssl_models_ckpt/' --max-epochs 1 --mse-btwin 'moco-mse'
# Out:
# /gpfs/home/ark576/.conda/envs/py37/lib/python3.7/site-packages/pl_bolts/utils/warnings.py:32: UserWarning: You want to use `gym` which is not installed yet, install it with `pip install gym`.
#   f' install it with `pip install {pypi_name}`.' + extra_text
# Namespace(batch_size=16, ckpt_path='/gpfs/data/razavianlab/home/ark576/ssl_models_ckpt/mocov2_all_augs_breast_cancer_hist_mse_0.25-0.25-0.25-0.25/epoch=0-val_loss=7.748.ckpt', data_path='/gpfs/data/razavianlab/home/ark576/datasets/breast-hist/', data_size=0.01, file_extension=None, from_scratch=False, max_epochs=1, mse_btwin='moco-mse', no_training=False, only_ll=False, save_path='/gpfs/data/razavianlab/home/ark576/ssl_models_ckpt/')
# Using 0.01 fraction of the data set for training
# /gpfs/home/ark576/.conda/envs/py37/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: Checkpoint directory /gpfs/data/razavianlab/home/ark576/ssl_models_ckpt/0.01/ exists and is not empty.
# ...
